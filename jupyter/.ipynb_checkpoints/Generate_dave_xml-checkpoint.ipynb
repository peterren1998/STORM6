# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment, indent

def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, encoding="ISO-8859-1")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="\t")

# %%
import numpy as np
import os
valve_ids = np.arange(1,16+1)
hyb_ids = np.arange(1,16+1)
reg_names = [f'u{_i}' for _i in np.arange(1,16+1)]

# %%
source_folder = r'D:\Pu\20210621-proB_Dox_CTP-08_colorswap'
target_drive = r'\\KOLMOGOROV\Chromatin_NAS_5'
imaging_protocol = r'Zscan_750_647_561_488_s60_n200'

# %%
cmd_seq = Element('command_sequence')

for _vid, _hid, _rname in zip(valve_ids, hyb_ids, reg_names):
    # comments
    comment = Comment(f"Hyb {_hid} for {_rname}")
    cmd_seq.append(comment)
    # TCEP
    tcep = SubElement(cmd_seq, 'valve_protocol')
    tcep.text = "Flow TCEP"
    # flow adaptor
    adt = SubElement(cmd_seq, 'valve_protocol')
    adt.text = f"Hybridize {_vid}"
    # delay time
    adt_incubation = SubElement(cmd_seq, 'delay')
    adt_incubation.text = "600000"
    # wash
    wash = SubElement(cmd_seq, 'valve_protocol')
    wash.text = "Short Wash"
    # readouts
    readouts = SubElement(cmd_seq, 'valve_protocol')
    readouts.text = "Flow Readouts"
    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H{_hid}{_rname.upper()}")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "5000"
    
    # hybridization loop
    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=imaging_protocol)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text#cmd_seq.findall('change_directory')[-1].text
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = True
    # empty line
    indent(target_dir)

# %%
print( prettify(cmd_seq))
# Out:
# <?xml version="1.0" ?>
# <command_sequence>
# 	<!--Hyb 1 for u1-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 1</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H1U1</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H1U1</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H1U1</target_path>
# 	</copy_directory>
# 	<!--Hyb 2 for u2-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 2</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H2U2</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H2U2</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H2U2</target_path>
# 	</copy_directory>
# 	<!--Hyb 3 for u3-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 3</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H3U3</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H3U3</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H3U3</target_path>
# 	</copy_directory>
# 	<!--Hyb 4 for u4-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 4</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H4U4</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H4U4</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H4U4</target_path>
# 	</copy_directory>
# 	<!--Hyb 5 for u5-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 5</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H5U5</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H5U5</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H5U5</target_path>
# 	</copy_directory>
# 	<!--Hyb 6 for u6-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 6</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H6U6</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H6U6</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H6U6</target_path>
# 	</copy_directory>
# 	<!--Hyb 7 for u7-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 7</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H7U7</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H7U7</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H7U7</target_path>
# 	</copy_directory>
# 	<!--Hyb 8 for u8-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 8</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H8U8</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H8U8</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H8U8</target_path>
# 	</copy_directory>
# 	<!--Hyb 9 for u9-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 9</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H9U9</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H9U9</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H9U9</target_path>
# 	</copy_directory>
# 	<!--Hyb 10 for u10-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 10</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H10U10</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H10U10</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H10U10</target_path>
# 	</copy_directory>
# 	<!--Hyb 11 for u11-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 11</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H11U11</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H11U11</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H11U11</target_path>
# 	</copy_directory>
# 	<!--Hyb 12 for u12-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 12</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H12U12</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H12U12</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H12U12</target_path>
# 	</copy_directory>
# 	<!--Hyb 13 for u13-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 13</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H13U13</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H13U13</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H13U13</target_path>
# 	</copy_directory>
# 	<!--Hyb 14 for u14-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 14</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H14U14</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H14U14</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H14U14</target_path>
# 	</copy_directory>
# 	<!--Hyb 15 for u15-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 15</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H15U15</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H15U15</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H15U15</target_path>
# 	</copy_directory>
# 	<!--Hyb 16 for u16-->
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Hybridize 16</valve_protocol>
# 	<delay>600000</delay>
# 	<valve_protocol>Short Wash</valve_protocol>
# 	<valve_protocol>Flow Readouts</valve_protocol>
# 	<change_directory>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H16U16</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s60_n200"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210621-proB_Dox_CTP-08_colorswap\H16U16</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210621-proB_Dox_CTP-08_colorswap\H16U16</target_path>
# 	</copy_directory>
# </command_sequence>
