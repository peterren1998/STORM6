# %%
# %run "C:\Users\neoSTORM6\Documents\ImageAnalysis3\required_files\Startup_py3.py"
sys.path.append(r"C:\Users\neoSTORM6\Documents")

import ImageAnalysis3 as ia
# %matplotlib notebook

from ImageAnalysis3 import *
print(os.getpid())
# Out:
# 20596

# %%
image_folder = r'D:\Pu\20230510-4T1_edits_11k_ns\H1M2'
image_folder = r'\\10.245.74.212\Chromatin_NAS_2\Pu\20230510-4T1_edits_11k_ns\H4M5'
image_basenames = sorted([_fl for _fl in os.listdir(image_folder) if _fl.split(os.extsep)[-1] =='dax'])
print(image_folder)
print(image_basenames)
# Out:
# \\10.245.74.212\Chromatin_NAS_2\Pu\20230510-4T1_edits_11k_ns\H4M5
# ...

# %%
image_filename = os.path.join(image_folder, image_basenames[-2])
image_filename = r'D:\Pu\20230510-4T1_edits_11k_ns\H6M7\Conv_zscan_124.dax'
print(image_filename)

im2 = ia.visual_tools.batch_load_dax(image_filename)

#split by channel
#image_channels = [750,647,561,488, 405]
image_channels = [750,647,561,488]
#image_channels = [647,488,405]
#image_channels = [750,647,488]
splitted_ims1 = ia.io_tools.load.split_im_by_channels(im2, 
                                                      image_channels,
                                                      image_channels,
                                                      num_buffer_frames=0, 
                                                      single_im_size=[50,2048,2048])
# Out:
# D:\Pu\20230510-4T1_edits_11k_ns\H6M7\Conv_zscan_124.dax

# %%
x
# Out:
# <img src="data:image/png;base64,..." width="768">

# %%
# %matplotlib notebook
f = plt.figure(dpi=120)
ia.visual_tools.imshow_mark_3d_v2(splitted_ims1, fig=f,
                                  image_names=image_channels, 
                                  #min_max_default=[1000,30000],
                                 )
# Out:
# <img src="data:image/png;base64,..." width="768">

# %%
# Out:
# array([ 434, -120])

# %%
(np.array([751,425]) -  np.array([317,545])) + (np.array([1769,1147]) -  np.array([1315,1287])) + (np.array([789,1561]) -  np.array([327,1679]))
# Out:
# array([1350, -378])

# %%
1350/3, -378/3
# Out:
# (450.0, -126.0)

# %%
np.array([-1376.8, 1578.4]) - np.array([450.0, -126.0]) * 0.108
# Out:
# array([-1363.192,  1529.8  ])

# %% [markdown]
# # Ref image

# %%
ref_image_filename = r'D:\Pu\20230510-4T1_edits_11k_ns\H6M7\test\zscan_750_647_561_488_s50_n250_0002.dax'
print(ref_image_filename)

ref_im = ia.visual_tools.batch_load_dax(ref_image_filename)

#split by channel
image_channels = [750,647,561,488]
splitted_ref_ims = ia.io_tools.load.split_im_by_channels(ref_im, 
                                                      image_channels,
                                                      image_channels,
                                                      num_buffer_frames=0, 
                                                      single_im_size=[50,2048,2048])
# Out:
# D:\Pu\20230510-4T1_edits_11k_ns\H6M7\test\zscan_750_647_561_488_s50_n250_0002.dax

# %%
# %matplotlib notebook
f = plt.figure(dpi=120)
ia.visual_tools.imshow_mark_3d_v2([splitted_ims1[-1],splitted_ref_ims[-1]], fig=f,
                                  #image_names=image_channels, 
                                  min_max_default=[1000,10000],
                                 )
# Out:
# <img src="data:image/png;base64,..." width="768">
# Exception ignored in: <function Reader.__del__ at 0x0000019AA6A55AF0>
# Traceback (most recent call last):
#   File "C:\Users\neoSTORM6\Documents\ImageAnalysis3\visual_tools.py", line 910, in __del__
#     if self.fileptr:
# AttributeError: 'DaxReader' object has no attribute 'fileptr'

# %%
# %matplotlib notebook
f = plt.figure(dpi=150)
ia.visual_tools.imshow_mark_3d_v2(splitted_ref_ims, fig=f,
                                  image_names=image_channels, min_max_default=[1000,30000])
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
# %matplotlib notebook
ia.visual_tools.imshow_mark_3d_v2([splitted_ims1[-2], splitted_ims2[-2]], )
# Out:
# <img src="data:image/png;base64,..." width="400">
