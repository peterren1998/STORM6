# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment, indent

def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, encoding="ISO-8859-1")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="\t")

# %%
import numpy as np
import os

valve_start =  1   #1 + 8 #19 + 9 
# H
hyb_start = 13 #67 # hyb1 skip 
#hyb_start = 1+24+24 #67 # hyb1 skip 
# R
#reg_start = 2+24+24 #26 
reg_start = 2

num_rounds = 9

add_ref_hyb = False

#data_type = 'L'
data_type = 'S'

valve_ids = np.arange(valve_start, valve_start + num_rounds)
hyb_ids = np.arange(hyb_start, hyb_start + num_rounds)
reg_names = [f'{data_type}{_i}' for _i in np.arange(reg_start, reg_start + num_rounds)]

# %%
source_folder = r'D:\Cosmos_HighRes\20240930_SpLi_test_trial1'

target_drive = r'\\10.245.74.212\Chromatin_NAS_3'
#target_drive = r'\\10.245.74.212\Chromatin_NAS_2'

# imaging protocol
imaging_protocol = r'Zscan_750_647_561_488_s50_n250_10Hz'

# reference imaging protocol
ref_imaging_protocol = r'Zscan_750_647_488_405_s50_n250_10Hz'
ref_hyb = 0
# bleach protocol
bleach = False
bleach_protocol = r'Bleach_750_647_561_s5'

add_10min_after_bleach = False

# %%
cmd_seq = Element('command_sequence')

if add_ref_hyb:
    # add hyb 0
    # comments
    comment = Comment(f"Hyb 0")
    cmd_seq.append(comment)
    # flow imaging buffer
    imaging = SubElement(cmd_seq, 'valve_protocol')
    imaging.text = f"Flow Imaging Buffer"

    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H0{data_type}1")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "15000"

    # imaging loop
    _im_p = ref_imaging_protocol

    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=_im_p)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text 
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"


for _i, (_vid, _hid, _rname) in enumerate(zip(valve_ids, hyb_ids, reg_names)):
    # select protocol
    _im_p = imaging_protocol
    # TCEP
    tcep = SubElement(cmd_seq, 'valve_protocol')
    tcep.text = "Hybridize 26"
    # incubate TCEP
    tcep_incubation = SubElement(cmd_seq, 'valve_protocol')
    tcep_incubation.text = f"Incubate 5min"
    # wash tcep
    tcep_wash = SubElement(cmd_seq, 'valve_protocol')
    tcep_wash.text = "Flow Wash Buffer"
        
    # comments
    comment = Comment(f"Hyb {_hid} with valve {_vid} for {_rname}")
    cmd_seq.append(comment)
    # flow adaptor
    adt = SubElement(cmd_seq, 'valve_protocol')
    adt.text = f"Hybridize {_vid}"
    if bleach:
        # delay time
        delay = SubElement(cmd_seq, 'delay')
        delay.text = "3000"
        # change directory
        bleach_change_dir = SubElement(cmd_seq, 'change_directory')
        bleach_change_dir.text = os.path.join(source_folder, f"Bleach")
        # wakeup
        bleach_wakeup = SubElement(cmd_seq, 'wakeup')
        bleach_wakeup.text = "15000"
        # imaging loop
        bleach_loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
        bleach_loop_item = SubElement(bleach_loop, 'item', name=bleach_protocol)
        bleach_loop_item.text = " "
        # delay time
        delay = SubElement(cmd_seq, 'delay')
        delay.text = "3000"
        # if add incubation after bleach
        if add_10min_after_bleach:
            # delay time
            adt_incubation = SubElement(cmd_seq, 'valve_protocol')
            adt_incubation.text = f"Incubate 10min"
               
    else:
        # delay time
        adt_incubation = SubElement(cmd_seq, 'valve_protocol')
        adt_incubation.text = f"Incubate 5min"
    # wash
    wash = SubElement(cmd_seq, 'valve_protocol')
    wash.text = "Flow Wash Buffer"
    
    # imager
    imager = SubElement(cmd_seq, 'valve_protocol')
    imager.text = "Flow 2xSSC"
    # incubate imager
    imager_incubation = SubElement(cmd_seq, 'valve_protocol')
    imager_incubation.text = f"Incubate 5min"
    # wash imager
    imager_wash = SubElement(cmd_seq, 'valve_protocol')
    imager_wash.text = f"Flow Wash Buffer"
    
    # readouts
    readouts = SubElement(cmd_seq, 'valve_protocol')
    #readouts.text = "Flow Common Readouts"
    readouts.text = "Flow Common Readouts"
    # incubate readouts
    readout_incubation = SubElement(cmd_seq, 'valve_protocol')
    readout_incubation.text = f"Incubate 5min"
    # wash readouts
    readout_wash = SubElement(cmd_seq, 'valve_protocol')
    readout_wash.text = f"Flow Wash Buffer"
    # flow imaging buffer
    imaging = SubElement(cmd_seq, 'valve_protocol')
    imaging.text = f"Flow Imaging Buffer"
    
    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H{_hid}{_rname.upper()}")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "15000"
    
    # imaging loop
    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=_im_p)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text#cmd_seq.findall('change_directory')[-1].text
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"
    # empty line
    indent(target_dir)

final_str = prettify(cmd_seq)
    
print( final_str )
# Out:
# <?xml version="1.0" ?>
# <command_sequence>
# 	<!--Hyb 0-->
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H0C1</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_405_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H0C1</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H0C1</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 1 with valve 1 for C2-->
# 	<valve_protocol>Hybridize 1</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H1C2</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H1C2</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H1C2</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 2 with valve 2 for C3-->
# 	<valve_protocol>Hybridize 2</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H2C3</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H2C3</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H2C3</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 3 with valve 3 for C4-->
# 	<valve_protocol>Hybridize 3</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H3C4</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H3C4</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H3C4</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 4 with valve 4 for C5-->
# 	<valve_protocol>Hybridize 4</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H4C5</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H4C5</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H4C5</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 5 with valve 5 for C6-->
# 	<valve_protocol>Hybridize 5</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H5C6</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H5C6</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H5C6</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 6 with valve 6 for C7-->
# 	<valve_protocol>Hybridize 6</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H6C7</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H6C7</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H6C7</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 7 with valve 7 for C8-->
# 	<valve_protocol>Hybridize 7</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H7C8</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H7C8</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H7C8</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 8 with valve 8 for C9-->
# 	<valve_protocol>Hybridize 8</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H8C9</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H8C9</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H8C9</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 9 with valve 9 for C10-->
# 	<valve_protocol>Hybridize 9</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H9C10</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H9C10</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H9C10</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 10 with valve 10 for C11-->
# 	<valve_protocol>Hybridize 10</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H10C11</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H10C11</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H10C11</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 11 with valve 11 for C12-->
# 	<valve_protocol>Hybridize 11</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H11C12</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H11C12</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H11C12</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Hybridize 26</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 12 with valve 12 for C13-->
# 	<valve_protocol>Hybridize 12</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow 2xSSC</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Common Readouts</valve_protocol>
# 	<valve_protocol>Incubate 5min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H12C13</change_directory>
# 	<wakeup>15000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_s50_n250_10Hz"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Cosmos_HighRes\20240930_SpLi_test_trial1\H12C13</source_path>
# 		<target_path>\\10.245.74.212\Chromatin_NAS_3\20240930_SpLi_test_trial1\H12C13</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# </command_sequence>

# %% [markdown]
# # save this xml

# %%
source_folder
# Out:
# 'D:\\Cosmos_HighRes\\20240930_SpLi_test_trial1'

# %%
save_filename = os.path.join(source_folder, f"generated_dave_H{hyb_start}-{hyb_start+num_rounds-1}.txt")
with open(save_filename, 'w') as _output_handle:
    print(save_filename)
    _output_handle.write(final_str)
# Out:
# D:\Cosmos_HighRes\20240930_SpLi_test_trial1\generated_dave_H1-12.txt
