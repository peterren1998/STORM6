# %%
from xml.etree import ElementTree
from xml.dom import minidom
from xml.etree.ElementTree import Element, SubElement, Comment, indent

def prettify(elem):
    """Return a pretty-printed XML string for the Element.
    """
    rough_string = ElementTree.tostring(elem, encoding="ISO-8859-1")
    reparsed = minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="\t")

# %%
import numpy as np
import os
valve_ids = np.arange(1, 24 +1)
hyb_ids = np.arange(1, 24 +1)
reg_names = [f'c{_i}' for _i in np.arange(2, 25 +1)]

# %%
source_folder = r'D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA'
target_drive = r'\\KOLMOGOROV\Chromatin_NAS_5'
imaging_protocol = r'Zscan_750_647_488_s50_n250'
ref_imaging_protocol = r'Zscan_750_647_561_488_405_s50_n250'
ref_hyb = -1

# %%
cmd_seq = Element('command_sequence')

# add hyb 0
# comments
comment = Comment(f"Hyb 0")
cmd_seq.append(comment)
# flow imaging buffer
imaging = SubElement(cmd_seq, 'valve_protocol')
imaging.text = f"Flow Imaging Buffer"

# change directory
change_dir = SubElement(cmd_seq, 'change_directory')
change_dir.text = os.path.join(source_folder, f"H0C1")
# wakeup
wakeup = SubElement(cmd_seq, 'wakeup')
wakeup.text = "5000"
    
# imaging loop
_im_p = ref_imaging_protocol

loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
loop_item = SubElement(loop, 'item', name=_im_p)
loop_item.text = " "
# delay time
delay = SubElement(cmd_seq, 'delay')
delay.text = "2000"
# copy folder
copy_dir = SubElement(cmd_seq, 'copy_directory')
source_dir = SubElement(copy_dir, 'source_path')
source_dir.text = change_dir.text 
target_dir = SubElement(copy_dir, 'target_path')
target_dir.text = os.path.join(target_drive, 
                               os.path.basename(os.path.dirname(source_dir.text)), 
                               os.path.basename(source_dir.text))
del_source = SubElement(copy_dir, 'delete_source')
del_source.text = "True"


for _i, (_vid, _hid, _rname) in enumerate(zip(valve_ids, hyb_ids, reg_names)):
    # select protocol
    _im_p = imaging_protocol
    # TCEP
    tcep = SubElement(cmd_seq, 'valve_protocol')
    tcep.text = "Flow TCEP"
    # wash tcep
    tcep_wash = SubElement(cmd_seq, 'valve_protocol')
    tcep_wash.text = "Flow Wash Buffer"
        
    # comments
    comment = Comment(f"Hyb {_hid} with {_vid} for {_rname}")
    cmd_seq.append(comment)
    # flow adaptor
    adt = SubElement(cmd_seq, 'valve_protocol')
    adt.text = f"Hybridize {_vid}"
    # delay time
    adt_incubation = SubElement(cmd_seq, 'valve_protocol')
    adt_incubation.text = f"Incubate 10min"
    # wash
    wash = SubElement(cmd_seq, 'valve_protocol')
    wash.text = "Flow Wash Buffer"
    
    # readouts
    readouts = SubElement(cmd_seq, 'valve_protocol')
    readouts.text = "Flow RNA common readouts"
    # incubate readouts
    readout_incubation = SubElement(cmd_seq, 'valve_protocol')
    readout_incubation.text = f"Incubate 10min"
    # wash readouts
    readout_wash = SubElement(cmd_seq, 'valve_protocol')
    readout_wash.text = f"Flow Wash Buffer"
    # flow imaging buffer
    imaging = SubElement(cmd_seq, 'valve_protocol')
    imaging.text = f"Flow Imaging Buffer"
    
    # change directory
    change_dir = SubElement(cmd_seq, 'change_directory')
    change_dir.text = os.path.join(source_folder, f"H{_hid}{_rname.upper()}")
    # wakeup
    wakeup = SubElement(cmd_seq, 'wakeup')
    wakeup.text = "5000"
    
    # imaging loop
    loop = SubElement(cmd_seq, 'loop', name='Position Loop Zscan', increment="name")
    loop_item = SubElement(loop, 'item', name=_im_p)
    loop_item.text = " "
    # delay time
    delay = SubElement(cmd_seq, 'delay')
    delay.text = "2000"
    # copy folder
    copy_dir = SubElement(cmd_seq, 'copy_directory')
    source_dir = SubElement(copy_dir, 'source_path')
    source_dir.text = change_dir.text#cmd_seq.findall('change_directory')[-1].text
    target_dir = SubElement(copy_dir, 'target_path')
    target_dir.text = os.path.join(target_drive, 
                                   os.path.basename(os.path.dirname(source_dir.text)), 
                                   os.path.basename(source_dir.text))
    del_source = SubElement(copy_dir, 'delete_source')
    del_source.text = "True"
    # empty line
    indent(target_dir)
print( prettify(cmd_seq))
# Out:
# <?xml version="1.0" ?>
# <command_sequence>
# 	<!--Hyb 0-->
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H0C1</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_561_488_405_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H0C1</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H0C1</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 1 with 1 for c2-->
# 	<valve_protocol>Hybridize 1</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H1C2</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H1C2</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H1C2</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 2 with 2 for c3-->
# 	<valve_protocol>Hybridize 2</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H2C3</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H2C3</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H2C3</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 3 with 3 for c4-->
# 	<valve_protocol>Hybridize 3</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H3C4</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H3C4</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H3C4</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 4 with 4 for c5-->
# 	<valve_protocol>Hybridize 4</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H4C5</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H4C5</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H4C5</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 5 with 5 for c6-->
# 	<valve_protocol>Hybridize 5</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H5C6</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H5C6</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H5C6</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 6 with 6 for c7-->
# 	<valve_protocol>Hybridize 6</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H6C7</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H6C7</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H6C7</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 7 with 7 for c8-->
# 	<valve_protocol>Hybridize 7</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H7C8</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H7C8</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H7C8</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 8 with 8 for c9-->
# 	<valve_protocol>Hybridize 8</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H8C9</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H8C9</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H8C9</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 9 with 9 for c10-->
# 	<valve_protocol>Hybridize 9</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H9C10</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H9C10</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H9C10</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 10 with 10 for c11-->
# 	<valve_protocol>Hybridize 10</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H10C11</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H10C11</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H10C11</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 11 with 11 for c12-->
# 	<valve_protocol>Hybridize 11</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H11C12</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H11C12</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H11C12</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 12 with 12 for c13-->
# 	<valve_protocol>Hybridize 12</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H12C13</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H12C13</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H12C13</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 13 with 13 for c14-->
# 	<valve_protocol>Hybridize 13</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H13C14</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H13C14</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H13C14</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 14 with 14 for c15-->
# 	<valve_protocol>Hybridize 14</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H14C15</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H14C15</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H14C15</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 15 with 15 for c16-->
# 	<valve_protocol>Hybridize 15</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H15C16</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H15C16</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H15C16</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 16 with 16 for c17-->
# 	<valve_protocol>Hybridize 16</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H16C17</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H16C17</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H16C17</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 17 with 17 for c18-->
# 	<valve_protocol>Hybridize 17</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H17C18</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H17C18</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H17C18</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 18 with 18 for c19-->
# 	<valve_protocol>Hybridize 18</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H18C19</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H18C19</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H18C19</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 19 with 19 for c20-->
# 	<valve_protocol>Hybridize 19</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H19C20</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H19C20</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H19C20</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 20 with 20 for c21-->
# 	<valve_protocol>Hybridize 20</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H20C21</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H20C21</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H20C21</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 21 with 21 for c22-->
# 	<valve_protocol>Hybridize 21</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H21C22</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H21C22</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H21C22</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 22 with 22 for c23-->
# 	<valve_protocol>Hybridize 22</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H22C23</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H22C23</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H22C23</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 23 with 23 for c24-->
# 	<valve_protocol>Hybridize 23</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H23C24</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H23C24</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H23C24</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# 	<valve_protocol>Flow TCEP</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<!--Hyb 24 with 24 for c25-->
# 	<valve_protocol>Hybridize 24</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow RNA common readouts</valve_protocol>
# 	<valve_protocol>Incubate 10min</valve_protocol>
# 	<valve_protocol>Flow Wash Buffer</valve_protocol>
# 	<valve_protocol>Flow Imaging Buffer</valve_protocol>
# 	<change_directory>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H24C25</change_directory>
# 	<wakeup>5000</wakeup>
# 	<loop name="Position Loop Zscan" increment="name">
# 		<item name="Zscan_750_647_488_s50_n250"> </item>
# 	</loop>
# 	<delay>2000</delay>
# 	<copy_directory>
# 		<source_path>D:\Pu\20210916-Thymus_WT_0522_CTP-10_DNA\H24C25</source_path>
# 		<target_path>\\KOLMOGOROV\Chromatin_NAS_5\20210916-Thymus_WT_0522_CTP-10_DNA\H24C25</target_path>
# 		<delete_source>True</delete_source>
# 	</copy_directory>
# </command_sequence>
